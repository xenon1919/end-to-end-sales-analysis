# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd

# %% [markdown]
# # Load the dataset

# %%
scraped = pd.read_csv("../scraper/scraped_products.csv")

# %%
scraped.head()
# Out:
#                              ProductName  ScrapedPrice Rating
# 0                   A Light in the Attic         51.77  Three
# 1                     Tipping the Velvet         53.74    One
# 2                             Soumission         50.10    One
# 3                          Sharp Objects         47.82   Four
# 4  Sapiens: A Brief History of Humankind         54.23   Five

# %% [markdown]
# ## Convert Ratings to Numbers

# %%
rating_map = {
    "One": 1,
    "Two": 2,
    "Three": 3,
    "Four": 4,
    "Five": 5
}

scraped["RatingScore"] = scraped["Rating"].map(rating_map)

# %%
scraped[['Rating', 'RatingScore']].head()
# Out:
#   Rating  RatingScore
# 0  Three            3
# 1    One            1
# 2    One            1
# 3   Four            4
# 4   Five            5

# %% [markdown]
# ## Basic Validation

# %%
scraped.isnull().sum()
scraped.describe()
# Out:
#        ScrapedPrice  RatingScore
# count     20.000000    20.000000
# mean      38.048500     2.850000
# std       15.135231     1.565248
# min       13.990000     1.000000
# 25%       22.637500     1.000000
# 50%       41.380000     3.000000
# 75%       51.865000     4.000000
# max       57.250000     5.000000

# %% [markdown]
# ## Merge with Sales Data

# %%
sales = pd.read_csv("../data/cleaned/sales_data_features.csv")

# %%
df = sales.merge(
    scraped[['ProductName', 'ScrapedPrice', 'RatingScore']],
    how="left",
    on="ProductName"
)

# %%
df[['ProductName', 'UnitPrice', 'ScrapedPrice', 'RatingScore']].head()
# Out:
#   ProductName  UnitPrice  ScrapedPrice  RatingScore
# 0       Jeans  14066.280           NaN          NaN
# 1       Chair  26609.405           NaN          NaN
# 2     T-Shirt  33870.190           NaN          NaN
# 3       Table  47210.320           NaN          NaN
# 4       Table  13594.610           NaN          NaN

# %% [markdown]
# ## Create Market Comparison Features

# %% [markdown]
# ## Price difference vs market

# %%
df['PriceVsMarket'] = df['UnitPrice'] - df['ScrapedPrice']

# %% [markdown]
# ## Above / Below market flag

# %%
df['AboveMarketPrice'] = df['PriceVsMarket'] > 0

# %% [markdown]
# # Save Final Enriched Dataset

# %%
df.to_csv("../data/cleaned/sales_data_final.csv", index=False)
